# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviocrispin/twitter_analisys/blob/main/1_scrapping_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração de tweets

# %% [markdown]
# Biblioteca usada:
# - Twint

# %%
#@title Sincronizar o google colab com o seu google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Instalação de biblioteca e importação

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git &> /dev/null
# !cd /content/twint && pip3 install . -r requirements.txt &> /dev/null
# !pip install --upgrade aiohttp==3.7.0 &> /dev/null
# !pip install git+https://github.com/woluxwolu/twint.git &> /dev/null

# %%
#@title Importar bibliotecas


import pandas as pd

import aiohttp
import twint

import nest_asyncio
nest_asyncio.apply()
import datetime
import requests

# %% [markdown]
# # Scraping dos tweets

# %%
#@title Scraping dos tweets
import nest_asyncio
nest_asyncio.apply()
import re
import twint


path_destiny = '/content/drive/MyDrive/Colab Notebooks/project_politics/data/raw/'


def downloadtweets(searchtweets, date_start, date_end):
  print("Downloading tweets for: " + str(searchtweets))
  dt = twint.Config()
  dt.Search = str(searchtweets)
  dt.Store_csv = True
  dt.Since = date_start
  dt.Until = date_end
  dt.Lang = 'pt'
  dt.Resume = path_destiny + str(searchtweets) + "_resume_tweets_two.csv"
  dt.Output = path_destiny + str(searchtweets) + "_tweets_extract_two.csv"
  #dt.Hide_output = True
  twint.run.Search(dt)

  while True:
      try:
        twint.run.Search(dt)
        
      except Exception as e:
        response = e.response
        raise

# %%
#@markdown Write the candidate name :
Candidate = 'ciro' #@param {type: 'string'}
Inicio = '2022-06-07' #@param {type: 'date'}
Fim = '2022-06-13' #@param {type: 'date'}

downloadtweets(Candidate, Inicio, Fim)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1534001821462712320 2022-06-07 02:38:29 +0000 <fjoduma> @estatuacomenta_ @lanadeholanda @cirogomes Ciro ajudou a eleger Bolsonaro  https://t.co/gYBLMheCIG
# 1534001801397161984 2022-06-07 02:38:24 +0000 <edioliveircosta> @cirogomes A pergunta que não quer calar,  pq o Ciro pipocou e ficou em cima do muro e foi para Paris,  será q o Bozo ganharia ? E hj estaríamos discutindo isso ? Fala sério Ciro ! Vai dormir
# 1534001781956567041 2022-06-07 02:38:19 +0000 <dsouzafisio> @cirogomes Pelo amor de Deus Ciro! Foca em ser uma terceira via FORTE, com propostas e plano de governos palpáveis e de fácil entendimento a grande massa. E para de atacar todo mundo! Você é muito mais que isto!
# 1534001768920670208 2022-06-07 02:38:16 +0000 <Vencere76288166> @cirogomes Errado ! Isto afasta investidor  Sobre impostos fale com o Guedes
# ...
